# %% [markdown]
# # EDA Explanatory data analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing datasets
clients_df = pd.read_csv("../data/processed/clients.csv")
products_df = pd.read_csv("../data/processed/products.csv")
transactions_df = pd.read_csv("../data/processed/transactions.csv")
documents_df = pd.read_csv("../data/processed/documents.csv")

# %% [markdown]
# # Clients

# %% [markdown]
# # Products

# %% [markdown]
# # Transactions

# %% [markdown]
# # Documents
